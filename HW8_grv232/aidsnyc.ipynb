# %%
import pandas as pd
import pylab as pl
import numpy as no
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfaids=pd.read_csv('aids.csv')

# %%
dfaids=dfaids.drop(['Notes'],1)

# %%
dfaids=dfaids.dropna(0,'any')

# %%
figsize(14,8)
pl.plot(dfaids[dfaids['Sex and Sexual Orientation']=='Female (any)'].groupby(['Year Reported Code'])['Cases'].sum()/1000)
pl.plot(dfaids[dfaids['Sex and Sexual Orientation']=='Male (bisexual)'].groupby(['Year Reported Code'])['Cases'].sum()/1000)
pl.plot(dfaids[dfaids['Sex and Sexual Orientation']=='Male (heterosexual or pediatric)'].groupby(['Year Reported Code'])['Cases'].sum()/1000)
pl.plot(dfaids[dfaids['Sex and Sexual Orientation']=='Male (homosexual)  or Unknown Classification'].groupby(['Year Reported Code'])['Cases'].sum()/1000)
pl.plot(dfaids.groupby(['Year Reported Code'])['Cases'].sum()/1000,'k')
#pl.axvline(x=1993,ls='dashed',color='k',alpha=0.8)
pl.text(1991.7,13.5,'AIDS main cause of dead men ages 25-44',rotation=80.5,fontsize=8.5)
pl.legend(['Women','Bisexual Men','Heterosexual Men','Homosexual Men','Total'])
pl.xlabel('Year',fontsize=12)
pl.ylabel('Number of reported cases in thousands',fontsize=12)
pl.title('Reported AIDS cases in NY from 1981 to 2002',fontsize=14)
pl.xticks(range(1981,2003),fontsize=9);

# %%
pl.axvline?

# %%
pl.text?
